# %% [markdown]
# # Data and Code Management

# %% [markdown]
# ### JSON Examples

# %%
import json
data = '''{
  "name" : "Chuck",
  "phone" : {
    "type" : "intl",
    "number" : "+1 734 303 4456"
   },
   "email" : {
     "hide" : "yes"
   }
}'''

info = json.loads(data)
print(type(data),type(info))

print('Name:',info["name"])
print('Hide:',info["email"]["hide"])
# Out:
# <class 'str'> <class 'dict'>
# Name: Chuck
# Hide: yes

# %%
import json
input = '''[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Chuck"
  }
]'''

info = json.loads(input)
print('User count:', len(info))
for item in info:
    print('Name', item['name'])
    print('Id', item['id'])
    print('Attribute', item['x'])
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Chuck
# Id 009
# Attribute 7

# %% [markdown]
# We can also move the json into a pandas DataFrame

# %%
import pandas as pd
df = pd.DataFrame(info)
df
# Out:
#     id  x   name
# 0  001  2  Chuck
# 1  009  7  Chuck

# %%
### When the schema is different
input = '''[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Chuck",
    "other" : "A value"
  }
]'''

info = json.loads(input)

df = pd.DataFrame(info)
df
# Out:
#     id  x   name    other
# 0  001  2  Chuck      NaN
# 1  009  7  Chuck  A value

# %% [markdown]
# ## Flask API Tutorial
# This tutorial will guide you through building a simple Flask API in Python.
#
# Flask library (install using pip install Flask)
#
# Learning Objectives:
#
# - Create a Flask application
# - Define routes for API endpoints
# - Handle different HTTP methods (GET, POST)
# - Return JSON data
# - Implement basic error handling
#
# Flask will not work in JupyterHub.  Students need to install Anaconda, PyCharm, VSCode or use Google Colab.
# You can obtain Anaconda [here](https://www.anaconda.com/download).

# %%
#pip install flask

# %% [markdown]
# This cell imports the Flask class and creates an instance of a Flask application named app. The __name__ variable refers to the current Python module. Setting debug=True enables Flask's debugger, which helps identify errors during development.
#
# It then defines a route for the root URL (/) using the @app.route decorator. The function hello_world will be executed when a GET request is made to this route. The function returns a string message, which will be the response sent back to the client.

# %%
from flask import Flask

app = Flask("First app")

# %%
@app.route("/")
def hello_world():
    return "<p>Hello, World!</p>"

# %%
# Run the Flask development server (optional for this cell)
app.run(host='localhost', port=5005)
# Out:
#  * Serving Flask app 'First app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5005
# Press CTRL+C to quit

# %% [markdown]
# This cell demonstrates how to create routes that accept variables. The <name> part in the URL pattern (/hello/<name>) is a placeholder that will be replaced with the actual value provided in the URL. The hello_name function receives this value as an argument named name. We use f-strings to dynamically create a greeting message that includes the provided name.

# %%
from flask import Flask

app = Flask("Second app")

@app.route('/hello/<name>')
def hello_name(name):
  # Use the `name` variable from the URL
  return f"Hello, {name}!"

# %%
app.run(host='localhost', port=5006)
#go to http://localhost:5006/hello/John
# Out:
#  * Serving Flask app 'Second app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [08/Jun/2025 17:55:15] "GET /Drkae HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jun/2025 17:55:15] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jun/2025 17:55:22] "GET /Drake/ HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jun/2025 17:55:31] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Jun/2025 17:55:34] "GET /hello/Drake HTTP/1.1" 200 -

# %% [markdown]
# This cell introduces handling different HTTP methods (GET and POST). When the user visits /form with a GET request, the first section of the form function is executed. Here, we return an HTML form that allows the user to enter their name in a text input field and submit it.
#
# When the user submits the form, a POST request is sent to the same URL (/form).

# %%
from flask import Flask, request


app = Flask("Third app")

@app.route('/form', methods=['GET', 'POST'])
def form():
    if request.method == 'GET':
        # Display a form for the user to input their name
        return '''<form method="POST">
                    <label for="username">Enter your name:</label>
                    <input type="text" name="username" id="username" placeholder="Enter your name">
                    <button type="submit">Submit</button>
                  </form>'''
    else:
        # Process the submitted form data
        try:
            username = request.form['username']
            return f"Hello, {username}!"
        except KeyError:
            # Handle the case where the 'username' key is not present in the form data
            return "Please enter your name in the form."

# %%
app.run(host='localhost', port=5006)
# http://localhost:5006/form
# Out:
#  * Serving Flask app 'Third app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [12/Jun/2025 00:33:50] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [12/Jun/2025 00:34:02] "GET /form HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2025 00:34:12] "POST /form HTTP/1.1" 200 -

# %% [markdown]
# # Assignment

# %% [markdown]
# You were introduced to the Python data types, structures, frames, formats, such as JSON and CSV, and interface. You have also been introduced to the Python Flask package for building web pages. The purpose of this assignment is to reinforce and assess your learning of the mentioned Python features through practice.

# %% [markdown]
# ## Question 1: Read the crunchbase_odm_orgs.csv CSV file into a Pandas data frame and drop records where company names are None values:
# - Print the count of records (rows) in the resulting data frame
# - Print the first 5 records of the data frame

# %%
import pandas as pd

crunchbase = pd.read_csv("crunchbase_odm_orgs.csv")
# crunchbase.info()
# info indicates that each row contains a company name
df1 = pd.DataFrame(crunchbase)
print('There are', len(df1), 'rows in the crunchbase CSV.')
print('First five records:')
df1.head(5)
# Out:
# There are 9999 rows in the crunchbase CSV.
# First five records:
#                                    uuid      name          type primary_role  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd  Wetpaint  organization      company
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7      Zoho  organization      company
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0      Digg  organization      company
# 3  df662812-7f97-0b43-9d3e-12f64f504fbb  Facebook  organization      company
# 4  b08efc27-da40-505a-6f9d-c9e14247bf36     Accel  organization     investor
#
#                                               cb_url        domain  \
# 0  https://www.crunchbase.com/organization/wetpai...  wetpaint.com
# 1  https://www.crunchbase.com/organization/zoho?u...      zoho.com
# 2  https://www.crunchbase.com/organization/digg?u...      digg.com
# 3  https://www.crunchbase.com/organization/facebo...  facebook.com
# 4  https://www.crunchbase.com/organization/accel?...     accel.com
#
#                homepage_url  \
# 0  http://www.wetpaint.com/
# 1     https://www.zoho.com/
# 2       http://www.digg.com
# 3   http://www.facebook.com
# 4      http://www.accel.com
#
#                                             logo_url  \
# 0  https://res.cloudinary.com/crunchbase-producti...
# 1  https://res.cloudinary.com/crunchbase-producti...
# 2  https://res.cloudinary.com/crunchbase-producti...
# 3  https://res.cloudinary.com/crunchbase-producti...
# 4  https://res.cloudinary.com/crunchbase-producti...
#
#                          facebook_url                     twitter_url  \
# 0   https://www.facebook.com/Wetpaint  https://twitter.com/wetpainttv
# 1        http://www.facebook.com/zoho         http://twitter.com/zoho
# 2        http://www.facebook.com/digg         http://twitter.com/digg
# 3  https://www.facebook.com/facebook/    https://twitter.com/facebook
# 4       http://www.facebook.com/accel        http://twitter.com/accel
#
#                                         linkedin_url combined_stock_symbols  \
# 0          https://www.linkedin.com/company/wetpaint                    NaN
# 1  http://www.linkedin.com/company/zoho-corporati...                    NaN
# 2               http://www.linkedin.com/company/digg                    NaN
# 3           http://www.linkedin.com/company/facebook              nasdaq:FB
# 4         https://www.linkedin.com/company/accel-vc/                    NaN
#
#          city      region country_code  \
# 0    New York    New York          USA
# 1  Pleasanton  California          USA
# 2    New York    New York          USA
# 3  Menlo Park  California          USA
# 4   Palo Alto  California          USA
#
#                                    short_description
# 0  Wetpaint offers an online social publishing pl...
# 1  Zoho offers a suite of business, collaboration...
# 2  Digg Inc. operates a website that enables its ...
# 3  Facebook is an online social networking servic...
# 4  Accel is an early and growth-stage venture cap...

# %% [markdown]
# ## Question 2: Create a data frame that contains only the records of USA-based companies whose name starts with "Ac":
# - Print the count of records (rows) in the resulting data frame
# - Print the first 5 records of the data frame

# %%
crunchbase_usa = df1[(df1['country_code']=='USA') & (df1['name'].str.startswith('Ac'))]

print('There are', len(crunchbase_usa), 'USA-based companies in the crunchbase CSV whose name start with Ac.')
crunchbase_usa#.head(5)
# Out:
# There are 31 USA-based companies in the crunchbase CSV whose name start with Ac.
#                                       uuid                       name  \
# 4     b08efc27-da40-505a-6f9d-c9e14247bf36                      Accel
# 186   ed54b2d5-f2f1-d4e9-9bbe-40961ff08d44              Action Engine
# 278   64a76f34-4e68-2eb6-d943-9465f39155cd               ActiveWorlds
# 1244  ef598b5b-d588-c21f-9b93-be78443f4e22                     Acquia
# 1879  135f427d-7f25-9492-1ffe-801b35b6b988  Academic Capital Exchange
# 2203  8b514862-2515-9a9a-768c-7f144a790863                 AccountNow
# 2223  64042128-fd87-8a30-228e-968c973027a0         Acendi Interactive
# 2437  9f9f4b5a-3634-1bbc-9f04-b941a7916edf            Act-On Software
# 3233  18b8cafd-f58f-515d-f888-5fd682f12317                 Active.com
# 3466  443b284c-9939-cbaa-e4e0-961b6819ab69        Activision Blizzard
# 3731  02104771-4d11-27a8-89e1-4556cc289373                  ActiVideo
# 3982  3afdfca1-99b7-7ea7-1557-e01a02c5413f              Acquity Group
# 3990  4b0033ae-8828-8192-f47e-88e058ef2854                Activeweave
# 4415  511468d6-b137-1539-6cb0-93219f6629ea                 ActiveHire
# 4438  9cd7cbfc-7319-90f9-9028-7696cdc431c0                  Accertify
# 4609  89d592e6-8e5b-dcd6-94c9-67819e61264b                     Acteva
# 5069  0563ff70-949d-0716-6847-1f72188c794a                 Ace Ticket
# 5276  9f290fdc-351c-f83a-d123-fbccffcb18f7                  Achievers
# 5385  634f908a-bfc4-4ffa-3c6a-812d777dc822               AccountMaven
# 5446  5a23908d-21f8-f7ea-dfb8-20dec5b8628d           Acumen Solutions
# 5834  155ed801-63f0-e5af-9106-e24069af9930             Academic Earth
# 5872  b68a1889-acc3-daf4-72c4-4c2038c58a68                 Accomplice
# 6029  037ea3d6-b0dc-64ea-6a88-9ade5174f9d2          Accipiter Systems
# 6054  41d88d51-b45f-83c8-341a-957027e036f7                ActiveCause
# 6344  beadacd3-b283-6e4e-33cf-0c1a1ac0ebca             AccuConference
# 6830  f29ce33d-4f82-6f24-6f8e-3d8e72ba51cc                     Acxiom
# 7431  ec346518-e5a7-2330-daa3-259992890c01               Academia.edu
# 7617  eebfcebc-5bea-6bce-3171-0c8f93bf943e                   Actacell
# 8360  032b7c55-5acd-3d4c-a8ca-d072aca7a45e                  ActiveWIT
# 8886  f2bec979-1d76-9393-d276-49df1327ef53      AccessSportsMedia.com
# 9083  ea208b00-8754-4f84-7a33-8d81b49be3e4         ActiveRideShop.com
#
#               type primary_role  \
# 4     organization     investor
# 186   organization      company
# 278   organization      company
# 1244  organization      company
# 1879  organization      company
# 2203  organization      company
# 2223  organization      company
# 2437  organization      company
# 3233  organization      company
# 3466  organization      company
# 3731  organization      company
# 3982  organization      company
# 3990  organization      company
# 4415  organization      company
# 4438  organization      company
# 4609  organization      company
# 5069  organization      company
# 5276  organization      company
# 5385  organization      company
# 5446  organization      company
# 5834  organization      company
# 5872  organization      company
# 6029  organization      company
# 6054  organization      company
# 6344  organization      company
# 6830  organization      company
# 7431  organization      company
# 7617  organization      company
# 8360  organization      company
# 8886  organization      company
# 9083  organization      company
#
#                                                  cb_url  \
# 4     https://www.crunchbase.com/organization/accel?...
# 186   https://www.crunchbase.com/organization/action...
# 278   https://www.crunchbase.com/organization/active...
# 1244  https://www.crunchbase.com/organization/acquia...
# 1879  https://www.crunchbase.com/organization/academ...
# 2203  https://www.crunchbase.com/organization/accoun...
# 2223  https://www.crunchbase.com/organization/acendi...
# 2437  https://www.crunchbase.com/organization/act-on...
# 3233  https://www.crunchbase.com/organization/active...
# 3466  https://www.crunchbase.com/organization/activi...
# 3731  https://www.crunchbase.com/organization/acivid...
# 3982  https://www.crunchbase.com/organization/acquit...
# 3990  https://www.crunchbase.com/organization/active...
# 4415  https://www.crunchbase.com/organization/active...
# 4438  https://www.crunchbase.com/organization/accert...
# 4609  https://www.crunchbase.com/organization/acteva...
# 5069  https://www.crunchbase.com/organization/ace-ti...
# 5276  https://www.crunchbase.com/organization/achiev...
# 5385  https://www.crunchbase.com/organization/accoun...
# 5446  https://www.crunchbase.com/organization/acumen...
# 5834  https://www.crunchbase.com/organization/academ...
# 5872  https://www.crunchbase.com/organization/accomp...
# 6029  https://www.crunchbase.com/organization/accipi...
# 6054  https://www.crunchbase.com/organization/active...
# 6344  https://www.crunchbase.com/organization/accuco...
# 6830  https://www.crunchbase.com/organization/acxiom...
# 7431  https://www.crunchbase.com/organization/academ...
# 7617  https://www.crunchbase.com/organization/actace...
# 8360  https://www.crunchbase.com/organization/active...
# 8886  https://www.crunchbase.com/organization/access...
# 9083  https://www.crunchbase.com/organization/active...
#
#                       domain                           homepage_url  \
# 4                  accel.com                   http://www.accel.com
# 186         actionengine.com            http://www.actionengine.com
# 278         activeworlds.com            http://www.activeworlds.com
# 1244              acquia.com                      http://acquia.com
# 1879      academicapital.com          http://www.academicapital.com
# 2203          accountnow.com                  http://accountnow.com
# 2223              acendi.com                  http://www.acendi.com
# 2437              act-on.com                  http://www.act-on.com
# 3233              active.com                  http://www.active.com
# 3466  activisionblizzard.com         https://activisionblizzard.com
# 3731    activevideotools.com  http://activevideotools.com/index.asp
# 3982        acquitygroup.com            http://www.acquitygroup.com
# 3990            blogrovr.com                http://www.blogrovr.com
# 4415          activehire.com              http://www.activehire.com
# 4438           accertify.com               http://www.accertify.com
# 4609        actevasucks.info            http://www.actevasucks.info
# 5069           aceticket.com             https://www.aceticket.com/
# 5276           achievers.com               http://www.achievers.com
# 5385        accountmaven.com            http://www.accountmaven.com
# 5446     acumensolutions.com         http://www.acumensolutions.com
# 5834       academicearth.org               http://academicearth.org
# 5872          accomplice.com              http://www.accomplice.com
# 6029    accipitersystems.com        http://www.accipitersystems.com
# 6054         activecause.com                 http://activecause.com
# 6344      accuconference.com          http://www.accuconference.com
# 6830              acxiom.com                  http://www.acxiom.com
# 7431            academia.edu              https://www.academia.edu/
# 7617            actacell.com                http://www.actacell.com
# 8360           activewit.com               http://www.ActiveWIT.com
# 8886   accesssportsmedia.com           http://accesssportsmedia.com
# 9083      activerideshop.com          http://www.activerideshop.com
#
#                                                logo_url  \
# 4     https://res.cloudinary.com/crunchbase-producti...
# 186   https://res.cloudinary.com/crunchbase-producti...
# 278   https://res.cloudinary.com/crunchbase-producti...
# 1244  https://res.cloudinary.com/crunchbase-producti...
# 1879  https://res.cloudinary.com/crunchbase-producti...
# 2203  https://res.cloudinary.com/crunchbase-producti...
# 2223  https://res.cloudinary.com/crunchbase-producti...
# 2437  https://res.cloudinary.com/crunchbase-producti...
# 3233  https://res.cloudinary.com/crunchbase-producti...
# 3466  https://res.cloudinary.com/crunchbase-producti...
# 3731  https://res.cloudinary.com/crunchbase-producti...
# 3982  https://res.cloudinary.com/crunchbase-producti...
# 3990  https://res.cloudinary.com/crunchbase-producti...
# 4415  https://res.cloudinary.com/crunchbase-producti...
# 4438  https://res.cloudinary.com/crunchbase-producti...
# 4609  https://res.cloudinary.com/crunchbase-producti...
# 5069  https://res.cloudinary.com/crunchbase-producti...
# 5276  https://res.cloudinary.com/crunchbase-producti...
# 5385  https://res.cloudinary.com/crunchbase-producti...
# 5446  https://res.cloudinary.com/crunchbase-producti...
# 5834  https://res.cloudinary.com/crunchbase-producti...
# 5872  https://res.cloudinary.com/crunchbase-producti...
# 6029  https://res.cloudinary.com/crunchbase-producti...
# 6054  https://res.cloudinary.com/crunchbase-producti...
# 6344  https://res.cloudinary.com/crunchbase-producti...
# 6830  https://res.cloudinary.com/crunchbase-producti...
# 7431  https://res.cloudinary.com/crunchbase-producti...
# 7617  https://res.cloudinary.com/crunchbase-producti...
# 8360  https://res.cloudinary.com/crunchbase-producti...
# 8886  https://res.cloudinary.com/crunchbase-producti...
# 9083  https://res.cloudinary.com/crunchbase-producti...
#
#                                            facebook_url  \
# 4                         http://www.facebook.com/accel
# 186                                                 NaN
# 278              http://www.facebook.com/activeworlds3d
# 1244                     http://www.facebook.com/acquia
# 1879                                                NaN
# 2203                 http://www.facebook.com/accountnow
# 2223                                                NaN
# 2437              http://www.facebook.com/actonsoftware
# 3233                  http://www.facebook.com/Activecom
# 3466  https://www.facebook.com/activision.blizzard.a...
# 3731                                                NaN
# 3982          http://www.facebook.com/acquitygroup/info
# 3990                                                NaN
# 4415              http://www.facebook.com/ActiveHireInc
# 4438                                                NaN
# 4609                https://www.facebook.com/Actevahelp
# 5069                 https://www.facebook.com/aceticket
# 5276         http://www.facebook.com/achieverscommunity
# 5385                                                NaN
# 5446            http://www.facebook.com/AcumenSolutions
# 5834             https://www.facebook.com/academicearth
# 5872                                                NaN
# 6029                                                NaN
# 6054                                                NaN
# 6344             http://www.facebook.com/accuconference
# 6830                 http://www.facebook.com/acxiomcorp
# 7431             https://www.facebook.com/Academia.edu/
# 7617                                                NaN
# 8360                                                NaN
# 8886         https://www.facebook.com/accesssportsmedia
# 9083         http://www.facebook.com/activerideshopfans
#
#                              twitter_url  \
# 4               http://twitter.com/accel
# 186                                  NaN
# 278    http://twitter.com/activeworlds3d
# 1244           http://twitter.com/Acquia
# 1879                                 NaN
# 2203       http://twitter.com/AccountNow
# 2223                                 NaN
# 2437    http://twitter.com/ActOnSoftware
# 3233           http://twitter.com/active
# 3466         https://twitter.com/atvi_ab
# 3731                                 NaN
# 3982     http://twitter.com/acquitygroup
# 3990                                 NaN
# 4415   http://twitter.com/ActiveHire_com
# 4438                                 NaN
# 4609      https://twitter.com/actevahelp
# 5069       https://twitter.com/aceticket
# 5276        http://twitter.com/Achievers
# 5385                                 NaN
# 5446  http://twitter.com/AcumenSolutions
# 5834    http://twitter.com/academicearth
# 5872                                 NaN
# 6029                                 NaN
# 6054      http://twitter.com/activecause
# 6344   http://twitter.com/accuconference
# 6830           http://twitter.com/acxiom
# 7431        https://twitter.com/academia
# 7617    https://www.twitter.com/actacell
# 8360                                 NaN
# 8886    http://twitter.com/AccessSports_
# 9083   http://twitter.com/ActiveRideShop
#
#                                            linkedin_url  \
# 4            https://www.linkedin.com/company/accel-vc/
# 186       https://www.linkedin.com/company/actionengine
# 278                                                 NaN
# 1244             http://www.linkedin.com/company/167056
# 1879                                                NaN
# 2203         http://www.linkedin.com/company/accountnow
# 2223                                                NaN
# 2437             http://www.linkedin.com/company/375185
# 3233                                                NaN
# 3466  https://www.linkedin.com/company/activision-bl...
# 3731                                                NaN
# 3982               http://www.linkedin.com/company/9700
# 3990                                                NaN
# 4415     http://www.linkedin.com/company/activehire-inc
# 4438            https://www.linkedin.com/company/339806
# 4609                                                NaN
# 5069  https://www.linkedin.com/company/ace-ticket-inc./
# 5276          http://www.linkedin.com/company/achievers
# 5385                                                NaN
# 5446                                                NaN
# 5834                                                NaN
# 5872                                                NaN
# 6029                                                NaN
# 6054                https://www.linkedin.com/in/hankejh
# 6344     http://www.linkedin.com/company/accuconference
# 6830             http://www.linkedin.com/company/acxiom
# 7431      https://www.linkedin.com/company/academia-edu
# 7617                                                NaN
# 8360                                                NaN
# 8886            http://www.linkedin.com/company/2675106
# 9083                                                NaN
#
#      combined_stock_symbols           city         region country_code  \
# 4                       NaN      Palo Alto     California          USA
# 186                     NaN    Foster City     California          USA
# 278                     NaN      Las Vegas         Nevada          USA
# 1244                    NaN         Boston  Massachusetts          USA
# 1879                    NaN        Chicago       Illinois          USA
# 2203                    NaN      San Ramon     California          USA
# 2223                    NaN  San Francisco     California          USA
# 2437                    NaN       Portland         Oregon          USA
# 3233                    NaN      San Diego     California          USA
# 3466            nasdaq:ATVI   Santa Monica     California          USA
# 3731                    NaN  Laguna Niguel     California          USA
# 3982             nysemkt:AQ        Chicago       Illinois          USA
# 3990                    NaN  San Francisco     California          USA
# 4415                    NaN         Austin          Texas          USA
# 4438                    NaN         Itasca       Illinois          USA
# 4609                    NaN  San Francisco     California          USA
# 5069                    NaN         Boston  Massachusetts          USA
# 5276                    NaN  San Francisco     California          USA
# 5385                    NaN  San Francisco     California          USA
# 5446                    NaN         Mclean       Virginia          USA
# 5834                    NaN  San Francisco     California          USA
# 5872                    NaN      Palo Alto     California          USA
# 6029                    NaN        Wexford   Pennsylvania          USA
# 6054                    NaN       New York       New York          USA
# 6344                    NaN     Fort Worth          Texas          USA
# 6830            nasdaq:ACXM    Little Rock       Arkansas          USA
# 7431                    NaN  San Francisco     California          USA
# 7617                    NaN         Austin          Texas          USA
# 8360                    NaN        Griffin        Georgia          USA
# 8886                    NaN    Los Angeles     California          USA
# 9083                    NaN      Mira Loma     California          USA
#
#                                       short_description
# 4     Accel is an early and growth-stage venture cap...
# 186   Action Engine is an agile software development...
# 278   Active Worlds is a 3D virtual reality platform...
# 1244  Acquia specializes in providing cloud-based di...
# 1879  Academic Capital Exchange (ACE), a peer-to-pee...
# 2203  AccountNow is a financial services company off...
# 2223  Acendi Interactive provides software-as-servic...
# 2437  Act-On Software’s cloud-based integrated marke...
# 3233  Active.com is an online community for people w...
# 3466  Activision Blizzard is an entertainment compan...
# 3731  ActiVideo is an audio-video components and sol...
# 3982  Acquity Group transforms businesses and create...
# 3990  Activeweave is a start-up operating in the att...
# 4415  ActiveHire offers a full-service job board tha...
# 4438  Accertify is a provider of fraud prevention, c...
# 4609  Acteva is an event registration service provid...
# 5069  Ace Ticket is a reseller of sports, concert, a...
# 5276  Achievers is a recognition and rewards softwar...
# 5385  AccountMaven is a global community of sales pe...
# 5446  Acumen is a business and technology consulting...
# 5834  Academic Earth offers a comprehensive collecti...
# 5872  Accomplice is a software application that help...
# 6029  Accipiter Systems develops data communications...
# 6054  ActiveCause brings together nonprofits, corpor...
# 6344  AccuConference offers audio and web conferenci...
# 6830  Acxiom is a SaaS-based company providing enter...
# 7431  Academia.edu is a platform for academics to sh...
# 7617  ActaCell develops materials for lithium-ion ba...
# 8360                       Web Hosting and Domain Names
# 8886  Access Sports Media is a multi-platform media ...
# 9083  Active Ride Shop provides the best product and...

# %% [markdown]
# ## Question 3: Convert the data frame from the previous step into a list of JSON objects:
# - Print the count of JSON objects
# - Print the first 5 JSON objects
# - Write all JSON objects into a text (JSON string) file
# - Print the number of records in the resulting file

# %%
import json

json_obj = crunchbase_usa.to_dict(orient='records') 
print("Count of JSON objects:", len(json_obj))

print("First 5 JSON objects:") 
for i in range(0, 5):
    print(json_obj[i])

with open('output.json', 'r') as file: 
    json_data = json.load(file) 

print("\nNumber of records in the resulting file:", len(json_data))
# Out:
# Count of JSON objects: 31
# First 5 JSON objects:
# {'uuid': 'b08efc27-da40-505a-6f9d-c9e14247bf36', 'name': 'Accel', 'type': 'organization', 'primary_role': 'investor', 'cb_url': 'https://www.crunchbase.com/organization/accel?utm_source=crunchbase&utm_medium=export&utm_campaign=odm_csv', 'domain': 'accel.com', 'homepage_url': 'http://www.accel.com', 'logo_url': 'https://res.cloudinary.com/crunchbase-production/image/upload/kxcwecxf439wsgluv7jv', 'facebook_url': 'http://www.facebook.com/accel', 'twitter_url': 'http://twitter.com/accel', 'linkedin_url': 'https://www.linkedin.com/company/accel-vc/', 'combined_stock_symbols': nan, 'city': 'Palo Alto', 'region': 'California', 'country_code': 'USA', 'short_description': 'Accel is an early and growth-stage venture capital firm that powers a global community of entrepreneurs.'}
# {'uuid': 'ed54b2d5-f2f1-d4e9-9bbe-40961ff08d44', 'name': 'Action Engine', 'type': 'organization', 'primary_role': 'company', 'cb_url': 'https://www.crunchbase.com/organization/actionengine?utm_source=crunchbase&utm_medium=export&utm_campaign=odm_csv', 'domain': 'actionengine.com', 'homepage_url': 'http://www.actionengine.com', 'logo_url': 'https://res.cloudinary.com/crunchbase-production/image/upload/ubyv0j9it0vpkefruxr4', 'facebook_url': nan, 'twitter_url': nan, 'linkedin_url': 'https://www.linkedin.com/company/actionengine', 'combined_stock_symbols': nan, 'city': 'Foster City', 'region': 'California', 'country_code': 'USA', 'short_description': 'Action Engine is an agile software development, design and data services agency'}
# {'uuid': '64a76f34-4e68-2eb6-d943-9465f39155cd', 'name': 'ActiveWorlds', 'type': 'organization', 'primary_role': 'company', 'cb_url': 'https://www.crunchbase.com/organization/activeworlds?utm_source=crunchbase&utm_medium=export&utm_campaign=odm_csv', 'domain': 'activeworlds.com', 'homepage_url': 'http://www.activeworlds.com', 'logo_url': 'https://res.cloudinary.com/crunchbase-production/image/upload/v1397180850/e53e7f472d5954396a2572c7d6548365.png', 'facebook_url': 'http://www.facebook.com/activeworlds3d', 'twitter_url': 'http://twitter.com/activeworlds3d', 'linkedin_url': nan, 'combined_stock_symbols': nan, 'city': 'Las Vegas', 'region': 'Nevada', 'country_code': 'USA', 'short_description': 'Active Worlds is a 3D virtual reality platform enabling users to build, enter and move about in worlds and interact with others.'}
# {'uuid': 'ef598b5b-d588-c21f-9b93-be78443f4e22', 'name': 'Acquia', 'type': 'organization', 'primary_role': 'company', 'cb_url': 'https://www.crunchbase.com/organization/acquia?utm_source=crunchbase&utm_medium=export&utm_campaign=odm_csv', 'domain': 'acquia.com', 'homepage_url': 'http://acquia.com', 'logo_url': 'https://res.cloudinary.com/crunchbase-production/image/upload/rbjvr1i7q5w5f430iavw', 'facebook_url': 'http://www.facebook.com/acquia', 'twitter_url': 'http://twitter.com/Acquia', 'linkedin_url': 'http://www.linkedin.com/company/167056', 'combined_stock_symbols': nan, 'city': 'Boston', 'region': 'Massachusetts', 'country_code': 'USA', 'short_description': 'Acquia specializes in providing cloud-based digital experience management solutions.'}
# {'uuid': '135f427d-7f25-9492-1ffe-801b35b6b988', 'name': 'Academic Capital Exchange', 'type': 'organization', 'primary_role': 'company', 'cb_url': 'https://www.crunchbase.com/organization/academic-capital-exchange?utm_source=crunchbase&utm_medium=export&utm_campaign=odm_csv', 'domain': 'academicapital.com', 'homepage_url': 'http://www.academicapital.com', 'logo_url': 'https://res.cloudinary.com/crunchbase-production/image/upload/v1397183889/5fe5afd0210d774cbb5b5061010fb9a0.jpg', 'facebook_url': nan, 'twitter_url': nan, 'linkedin_url': nan, 'combined_stock_symbols': nan, 'city': 'Chicago', 'region': 'Illinois', 'country_code': 'USA', 'short_description': 'Academic Capital Exchange (ACE), a peer-to-peer student loan marketplace, helps students obtain financial support and professional guidance.'}
#
# Number of records in the resulting file: 31

# %% [markdown]
# ## Question 4: Read the JSON objects from the created file back into a data frame, filter for companies based in New York (city):
# - Print the records in the resulting data frame
# - Write the output to a webpage using Flask

# %%
from flask import Flask, request

df = pd.DataFrame(json_obj) 
companies_ny = df[df['city'] == 'New York']

print('NY based companies:')
companies_ny
# Out:
# NY based companies:
#                                     uuid         name          type  \
# 23  41d88d51-b45f-83c8-341a-957027e036f7  ActiveCause  organization
#
#    primary_role                                             cb_url  \
# 23      company  https://www.crunchbase.com/organization/active...
#
#              domain            homepage_url  \
# 23  activecause.com  http://activecause.com
#
#                                              logo_url facebook_url  \
# 23  https://res.cloudinary.com/crunchbase-producti...          NaN
#
#                        twitter_url                         linkedin_url  \
# 23  http://twitter.com/activecause  https://www.linkedin.com/in/hankejh
#
#    combined_stock_symbols      city    region country_code  \
# 23                    NaN  New York  New York          USA
#
#                                     short_description
# 23  ActiveCause brings together nonprofits, corpor...

# %% [markdown]
# ## Question 5: Implement Flask API functions to Return a list of Crunchbase companies based in a user submitted City from the original dataset (4 Points)
# - Take a user input through a form to return a list of JSON objects from the city queried

# %%
from flask import Flask, request


app = Flask("Company Locator")

@app.route('/form', methods=['GET', 'POST'])
def form():
    if request.method == 'GET':
        # Display a form for the user to input their name
        return '''<form method="POST">
                    <label for="city_name">Enter the name of a city to locate companies:</label>
                    <input type="str" name="city_name" id="city_name" placeholder="City Name">
                    <button type="submit">Submit</button>
                  </form>'''
    else:
        city_name = request.form['city_name']
        df2 = df1[(df1['city']== city_name)]
        json_obj2 = df2.to_dict(orient='records')
        return json_obj2

# %%
app.run(host='localhost', port=5006)
# http://localhost:5006/form
# Out:
#  * Serving Flask app 'Company Locator'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5006
# Press CTRL+C to quit
# 127.0.0.1 - - [12/Jun/2025 13:23:21] "GET /form HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Jun/2025 13:23:25] "POST /form HTTP/1.1" 200 -

# %% [markdown]
# ## Question 6: Git Version Control
#
# - Initialize a Git repository for your project directory.
# - Commit your code (data.py, Flask application script) with a descriptive message (e.g., "Initial commit: Flask API with data and route").
# - Push your code to a remote Git repository (e.g., GitHub). Submit the repository URL in the answer cell.

# %%
#Write git repo link

# %% [markdown]
# # Assignment End
